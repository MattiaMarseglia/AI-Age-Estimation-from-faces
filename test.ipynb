# %%
# Mount your Drive - After doing this step, your Google Drive folders are accessible from Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir('/content/gdrive/Shareddrives/Consegna_Artificial_Vision_Gruppo12/consegna')

# %%
# !pip install -r requirement.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: brotlipy==0.7.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 1)) (0.7.0)
# Requirement already satisfied: contourpy==1.0.6 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 2)) (1.0.6)
# Requirement already satisfied: cycler==0.11.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 3)) (0.11.0)
# Requirement already satisfied: dlib==19.24.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 4)) (19.24.0)
# Requirement already satisfied: facenet-pytorch==2.5.2 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 5)) (2.5.2)
# Requirement already satisfied: fonttools==4.38.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 6)) (4.38.0)
# Requirement already satisfied: joblib==1.2.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 7)) (1.2.0)
# Requirement already satisfied: kiwisolver==1.4.4 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 8)) (1.4.4)
# Requirement already satisfied: matplotlib==3.6.2 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 9)) (3.6.2)
# Requirement already satisfied: mkl-fft==1.3.1 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 10)) (1.3.1)
# Requirement already satisfied: mkl-service==2.4.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 11)) (2.4.0)
# Requirement already satisfied: numpy==1.22.3 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 12)) (1.22.3)
# Requirement already satisfied: opencv-python==4.7.0.68 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 13)) (4.7.0.68)
# Requirement already satisfied: pandas==1.5.2 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 14)) (1.5.2)
# Requirement already satisfied: Pillow==9.3.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 15)) (9.3.0)
# Requirement already satisfied: pyparsing==3.0.9 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 16)) (3.0.9)
# Requirement already satisfied: pytz==2022.7 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 17)) (2022.7)
# Requirement already satisfied: scikit-learn==1.2.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 18)) (1.2.0)
# Requirement already satisfied: scipy==1.9.3 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 19)) (1.9.3)
# Requirement already satisfied: seaborn==0.12.2 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 20)) (0.12.2)
# Requirement already satisfied: threadpoolctl==3.1.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 21)) (3.1.0)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 22)) (1.13.1+cu116)
# Requirement already satisfied: torchaudio==0.13.1 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 23)) (0.13.1+cu116)
# Requirement already satisfied: torchmetrics==0.11.0 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 24)) (0.11.0)
# Requirement already satisfied: torchscan==0.1.2 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 25)) (0.1.2)
# Requirement already satisfied: torchvision==0.14.1 in /usr/local/lib/python3.8/dist-packages (from -r requirement.txt (line 26)) (0.14.1+cu116)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from brotlipy==0.7.0->-r requirement.txt (line 1)) (1.15.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from facenet-pytorch==2.5.2->-r requirement.txt (line 5)) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.6.2->-r requirement.txt (line 9)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.6.2->-r requirement.txt (line 9)) (23.0)
# Requirement already satisfied: dpcpp_cpp_rt in /usr/local/lib/python3.8/dist-packages (from mkl-fft==1.3.1->-r requirement.txt (line 10)) (2023.0.0)
# Requirement already satisfied: mkl in /usr/local/lib/python3.8/dist-packages (from mkl-fft==1.3.1->-r requirement.txt (line 10)) (2019.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from mkl-service==2.4.0->-r requirement.txt (line 11)) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r requirement.txt (line 22)) (4.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0.0->brotlipy==0.7.0->-r requirement.txt (line 1)) (2.21)
# Requirement already satisfied: intel-cmplr-lic-rt==2023.0.0 in /usr/local/lib/python3.8/dist-packages (from dpcpp_cpp_rt->mkl-fft==1.3.1->-r requirement.txt (line 10)) (2023.0.0)
# Requirement already satisfied: intel-cmplr-lib-rt==2023.0.0 in /usr/local/lib/python3.8/dist-packages (from dpcpp_cpp_rt->mkl-fft==1.3.1->-r requirement.txt (line 10)) (2023.0.0)
# Requirement already satisfied: intel-openmp==2023.0.0 in /usr/local/lib/python3.8/dist-packages (from dpcpp_cpp_rt->mkl-fft==1.3.1->-r requirement.txt (line 10)) (2023.0.0)
# Requirement already satisfied: intel-opencl-rt==2023.0.0 in /usr/local/lib/python3.8/dist-packages (from dpcpp_cpp_rt->mkl-fft==1.3.1->-r requirement.txt (line 10)) (2023.0.0)
# Requirement already satisfied: tbb==2021.* in /usr/local/lib/python3.8/dist-packages (from intel-opencl-rt==2023.0.0->dpcpp_cpp_rt->mkl-fft==1.3.1->-r requirement.txt (line 10)) (2021.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->facenet-pytorch==2.5.2->-r requirement.txt (line 5)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->facenet-pytorch==2.5.2->-r requirement.txt (line 5)) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->facenet-pytorch==2.5.2->-r requirement.txt (line 5)) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->facenet-pytorch==2.5.2->-r requirement.txt (line 5)) (1.24.3)

# %%
# Run the test
# --data is the file with the annotations. Use the provided foo_test.csv to check if your code works.
# --images is the path of the folder with the images listed in --data. Use the provided foo_test/ to check if your code works.
# --results is the file on which the predictions of your model should be written. A sample foo_results.csv is provided.
# !python test.py --data utils/foo_test.csv --images utils/foo_test/ --results utils/foo_results.csv
# Out:
# 1
# cuda
# 10
# 100% 10/10 [00:02<00:00,  3.36it/s]

# %%
# Run the test
# --data is the file with the annotations. Use the provided foo_test.csv to check if your code works.
# --images is the path of the folder with the images listed in --data. Use the provided foo_test/ to check if your code works.
# --results is the file on which the predictions of your model should be written. A sample foo_results.csv is provided.
# !python testFast.py --data utils/foo_test.csv --images utils/foo_test/ --results utils/foo_results2.csv
# Out:
# 1
# cuda
